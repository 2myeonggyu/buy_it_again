# %%
install.packages("xlsx", repos = 'http://cran.us.r-project.org')
# Out:
# also installing the dependencies ‘rJava’, ‘xlsxjars’
#
# Warning message in install.packages("xlsx", repos = "http://cran.us.r-project.org"):
# “installation of package ‘rJava’ had non-zero exit status”Warning message in install.packages("xlsx", repos = "http://cran.us.r-project.org"):
# “installation of package ‘xlsxjars’ had non-zero exit status”Warning message in install.packages("xlsx", repos = "http://cran.us.r-project.org"):
# “installation of package ‘xlsx’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
dat = read.csv("diaper_drop0.csv")

# %%
dat[,2]
# Out:
#        X      time
# 1       2      23
# 2       4      59
# 3       6      31
# 4       7      23
# 5       8      60
# 6       9       8
# 7      11      53
# 8      14     148
# 9      15      32
# 10     17      29
# 11     19      56
# 12     20      33
# 13     24      89
# 14     27      55
# 15     28      67
# 16     29      33
# 17     31      41
# 18     32      41
# 19     33      18
# 20     34      28
# 21     36      31
# 22     38      31
# 23     39      27
# 24     40      34
# 25     41      89
# 26     46      66
# 27     48      57
# 28     49      27
# 29     50      20
# 30     51      22
# ⋮      ⋮      ⋮
# 275735 541411 1
# 275736 541413 2
# 275737 541419 3
# 275738 541497 3
# 275739 541526 1
# 275740 541554 3
# 275741 541568 3
# 275742 541658 1
# 275743 541686 3
# 275744 541690 3
# 275745 541693 3
# 275746 541731 2
# 275747 541775 1
# 275748 541780 1
# 275749 541786 2
# 275750 541788 3
# 275751 541791 3
# 275752 541920 1
# 275753 541974 3
# 275754 542046 2
# 275755 542129 2
# 275756 542224 1
# 275757 542248 2
# 275758 542269 2
# 275759 542342 2
# 275760 542474 2
# 275761 542584 1
# 275762 542695 1
# 275763 542745 1
# 275764 543331 1

# %%
# nan값 제거

dat = na.omit(dat)

# %%
dat
# Out:
#        X      X0
# 2       1       0
# 3       2      23
# 5       4      59
# 6       5       0
# 7       6      31
# 8       7      23
# 9       8      60
# 10      9       8
# 12     11      53
# 15     14     148
# 16     15      32
# 18     17      29
# 20     19      56
# 21     20      33
# 24     23       0
# 25     24      89
# 28     27      55
# 29     28      67
# 30     29      33
# 32     31      41
# 33     32      41
# 34     33      18
# 35     34      28
# 37     36      31
# 39     38      31
# 40     39      27
# 41     40      34
# 42     41      89
# 45     44       0
# 47     46      66
# ⋮      ⋮      ⋮
# 545489 545488 0
# 545504 545503 0
# 545505 545504 0
# 545506 545505 0
# 545518 545517 0
# 545524 545523 0
# 545530 545529 0
# 545533 545532 0
# 545541 545540 0
# 545549 545548 0
# 545558 545557 0
# 545559 545558 0
# 545566 545565 0
# 545567 545566 0
# 545568 545567 0
# 545585 545584 0
# 545596 545595 0
# 545614 545613 0
# 545640 545639 0
# 545641 545640 0
# 545656 545655 0
# 545674 545673 0
# 545678 545677 0
# 545679 545678 0
# 545688 545687 0
# 545689 545688 0
# 545713 545712 0
# 545719 545718 0
# 545725 545724 0
# 545750 545749 0

# %%
dat = subset(dat, select=c("time"))

# %%
install.packages("MASS", repos='http://cran.us.r-project.org')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library('MASS')

# %%
dat = as.matrix(dat)

# %%
fitdistr(dat, dgamma, start=list(shape=0.1, scale=0.1))
# Out:
# Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”Warning message in densfun(x, parm[1], parm[2], ...):
# “NaN이 생성되었습니다”
#       shape          scale
#    1.469631198   24.294852175
#  ( 0.003597496) ( 0.070662738)
